# %% [markdown]
# ## Importing Modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_palette("viridis")

# %% [markdown]
# ## Read Data from file

# %%
df = pd.read_csv("../USA_Housing.csv")

# %% [markdown]
# ## Overview of data

# %%
df.head() #Top 4 features of Dataset
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0       79545.45857             5.682861                   7.009188
# 1       79248.64245             6.002900                   6.730821
# 2       61287.06718             5.865890                   8.512727
# 3       63345.24005             7.188236                   5.586729
# 4       59982.19723             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price
# 0                          4.09      23086.80050  1.059034e+06
# 1                          3.09      40173.07217  1.505891e+06
# 2                          5.13      36882.15940  1.058988e+06
# 3                          3.26      34310.24283  1.260617e+06
# 4                          4.23      26354.10947  6.309435e+05

# %%
df.info() #Information of Dataset like Datatype | Count | Non-Null
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
# dtypes: float64(6)
# memory usage: 234.5 KB

# %%
df.columns #Columns/Featrues of Dataset
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price'],
#       dtype='object')

# %% [markdown]
# ## Data Pre-Processing

# %%
df.describe() #Describing Data Statistically
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562390             5.322283                   6.299250
# 50%        68804.286405             5.970429                   7.002902
# 75%        75783.338665             6.650808                   7.665871
# max       107701.748400             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
df.isnull().sum() #Is there any Null values in Dataset - Checking null values
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# dtype: int64

# %%
# Descriptive Analysis of all features of Dataset

from Stats import cal_stats

for col in df.columns:
    cal_stats(col, df[col])
    print('-'*100)
# Out:
# Avg. Area Income
# Total Sum 342915544.91985
# Total Count 5000
# Minimum 17796.63119
# Maximum 107701.7484
# Range 89905.12
# Average 68583.11
# Median 68804.29
# Mode ModeResult(mode=17796.63119, count=1)
# Q1 61480.56239
# Q3 75783.33866499999
# IQR 14302.77627499999
# Lower Whisker 40026.39797750002
# Upper Whisker 97237.50307749998
# Variance 113570058.15998553
# Standard Deviation 10656.92536147202
# Skewness -0.03370985850476661
# Kurtosis 0.044328500390600656
# ----------------------------------------------------------------------------------------------------
# Avg. Area House Age
# Total Sum 29886.110176435002
# Total Count 5000
# Minimum 2.644304186
# Maximum 9.519088066
# Range 6.87
# Average 5.98
# Median 5.97
# Mode ModeResult(mode=2.644304186, count=1)
# Q1 5.32228301575
# Q3 6.65080847925
# IQR 1.3285254635000001
# Lower Whisker 3.3294948205
# Upper Whisker 8.6435966745
# Variance 0.9827887594565952
# Standard Deviation 0.9913570292566625
# ...

# %% [markdown]
# ## Visualization Plots

# %%
# Distribution Plot of all features of Dataset

for col in df.columns:
    sns.displot(df[col])
    plt.show()

# %%
# kDE (Kernel Density Estimation) Plot of all features of Dataset


for col in df.columns:
    sns.kdeplot(df[col])
    plt.show()

# %%
# Violin Plot of all features of Dataset

for col in df.columns:
    sns.violinplot(df[col])
    plt.show()

# %%
# Correlation Heatmap

sns.heatmap(df.corr(), annot=True, cmap='viridis', vmax=1, vmin=-1)
# Out:
# <Axes: >

# %% [markdown]
# ## Model Building

# %%
X = df.drop('Price', axis=1)
y = df['Price']

# %%
# train-test-split for cross validation

from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Splitted Data
[X_train.shape, X_test.shape, y_train.shape, y_test.shape]
# Out:
# [(4000, 5), (1000, 5), (4000,), (1000,)]

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Y-intercept of line
lr.intercept_
# Out:
# -2628123.4610886266

# %%
# Slopes for each features
lr.coef_
# Out:
# array([2.15916763e+01, 1.65165734e+05, 1.19819543e+05, 1.42840678e+03,
#        1.51604140e+01])

# %%
y_pred = lr.predict(X_test)

# %%
# Sum of Squared Error
sme = sum((y_pred-y_test)**2)
print("Sum of Squared Error", sme)

# Mean Squared Error
mse = sum((y_pred-y_test)**2)/1000
print("Mean Squared Error", mse)

# Root Mean Squared Error
rmse = np.sqrt(sum((y_pred-y_test)**2)/1000)
print("Root Mean Squared Error", rmse)
# Out:
# Sum of Squared Error 9625626318106.541
# Mean Squared Error 9625626318.10654
# Root Mean Squared Error 98110.2763124564

# %%
# It's showing that model can make error of $98110 for Price of per house

# %%
df['Price'].mean()

# see, for mean Price of $1232072, I think $98110 would be understandable error
# Out:
# 1232072.6541453

# %%
# Distribution Plot of errors

sns.displot(y_pred-y_test)

# It shows nearly, majority of errors are near to zero, as it seems a normal distribution
